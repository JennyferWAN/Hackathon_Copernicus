# %%
# !pip install segment-geospatial
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 62.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 75.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 33.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 70.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 62.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 29.5 MB/s eta 0:00:00
# ...

# %%
# !pip install leafmap Pillow

# %%
import leafmap

# %%
img0 = "/content/img0.jpeg"
img1 = "/content/img1.jpeg"
img2 = "/content/img2.jpeg"
img3 = "/content/img3.jpeg"
img4 = "/content/img4.jpeg"
img5 = "/content/img5.jpeg"
img6 = "/content/img6.jpeg"
img7 = "/content/img7.jpeg"
img8 = "/content/img8.jpeg"
img9 = "/content/img9.jpeg"
img10 = "/content/img10.jpeg"
img11 = "/content/img11.jpeg"

# %%
leafmap.image_comparison(
    img0,
    img1,
    label1='Satellite Image',
    label2='Image Segmentation',
    starting_position=50,
    out_html='image_comparison0.html',
)
# Out:
#         <html>
#         <head>
#         <style>body { margin: unset; }</style>
#         <link rel="stylesheet" href="https://cdn.knightlab.com/libs/juxtapose/latest/css/juxtapose.css">
#         <script src="https://cdn.knightlab.com/libs/juxtapose/latest/js/juxtapose.min.js"></script>
#         <div id="foo" style="height: 648; width: 704;"></div>
#         <script>
#         slider = new juxtapose.JXSlider('#foo',
#             [
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Satellite Image',
#                 },
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Image Segmentation',
#                 }
#             ],
#             {
#                 animate: true,
#                 showLabels: true,
#                 showCredits: true,
#                 startingPosition: "50%",
#                 makeResponsive: true,
#             });
#         </script>
# ...

# %%
leafmap.image_comparison(
    img2,
    img3,
    label1='Satellite Image',
    label2='Image Segmentation',
    starting_position=50,
    out_html='image_comparison1.html',
)
# Out:
#         <html>
#         <head>
#         <style>body { margin: unset; }</style>
#         <link rel="stylesheet" href="https://cdn.knightlab.com/libs/juxtapose/latest/css/juxtapose.css">
#         <script src="https://cdn.knightlab.com/libs/juxtapose/latest/js/juxtapose.min.js"></script>
#         <div id="foo" style="height: 648; width: 704;"></div>
#         <script>
#         slider = new juxtapose.JXSlider('#foo',
#             [
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Satellite Image',
#                 },
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Image Segmentation',
#                 }
#             ],
#             {
#                 animate: true,
#                 showLabels: true,
#                 showCredits: true,
#                 startingPosition: "50%",
#                 makeResponsive: true,
#             });
#         </script>
# ...

# %%
leafmap.image_comparison(
    img4,
    img5,
    label1='Satellite Image',
    label2='Image Segmentation',
    starting_position=50,
    out_html='image_comparison1.html',
)
# Out:
#         <html>
#         <head>
#         <style>body { margin: unset; }</style>
#         <link rel="stylesheet" href="https://cdn.knightlab.com/libs/juxtapose/latest/css/juxtapose.css">
#         <script src="https://cdn.knightlab.com/libs/juxtapose/latest/js/juxtapose.min.js"></script>
#         <div id="foo" style="height: 648; width: 704;"></div>
#         <script>
#         slider = new juxtapose.JXSlider('#foo',
#             [
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Satellite Image',
#                 },
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Image Segmentation',
#                 }
#             ],
#             {
#                 animate: true,
#                 showLabels: true,
#                 showCredits: true,
#                 startingPosition: "50%",
#                 makeResponsive: true,
#             });
#         </script>
# ...

# %%
leafmap.image_comparison(
    img6,
    img7,
    label1='Satellite Image',
    label2='Image Segmentation',
    starting_position=50,
    out_html='image_comparison3.html',
)
# Out:
#         <html>
#         <head>
#         <style>body { margin: unset; }</style>
#         <link rel="stylesheet" href="https://cdn.knightlab.com/libs/juxtapose/latest/css/juxtapose.css">
#         <script src="https://cdn.knightlab.com/libs/juxtapose/latest/js/juxtapose.min.js"></script>
#         <div id="foo" style="height: 648; width: 704;"></div>
#         <script>
#         slider = new juxtapose.JXSlider('#foo',
#             [
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Satellite Image',
#                 },
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Image Segmentation',
#                 }
#             ],
#             {
#                 animate: true,
#                 showLabels: true,
#                 showCredits: true,
#                 startingPosition: "50%",
#                 makeResponsive: true,
#             });
#         </script>
# ...

# %%
leafmap.image_comparison(
    img8,
    img9,
    label1='Satellite Image',
    label2='Image Segmentation',
    starting_position=50,
    out_html='image_comparison4.html',
)
# Out:
#         <html>
#         <head>
#         <style>body { margin: unset; }</style>
#         <link rel="stylesheet" href="https://cdn.knightlab.com/libs/juxtapose/latest/css/juxtapose.css">
#         <script src="https://cdn.knightlab.com/libs/juxtapose/latest/js/juxtapose.min.js"></script>
#         <div id="foo" style="height: 648; width: 704;"></div>
#         <script>
#         slider = new juxtapose.JXSlider('#foo',
#             [
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Satellite Image',
#                 },
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Image Segmentation',
#                 }
#             ],
#             {
#                 animate: true,
#                 showLabels: true,
#                 showCredits: true,
#                 startingPosition: "50%",
#                 makeResponsive: true,
#             });
#         </script>
# ...

# %%
leafmap.image_comparison(
    img10,
    img11,
    label1='Satellite Image',
    label2='Image Segmentation',
    starting_position=50,
    out_html='image_comparison5.html',
)
# Out:
#         <html>
#         <head>
#         <style>body { margin: unset; }</style>
#         <link rel="stylesheet" href="https://cdn.knightlab.com/libs/juxtapose/latest/css/juxtapose.css">
#         <script src="https://cdn.knightlab.com/libs/juxtapose/latest/js/juxtapose.min.js"></script>
#         <div id="foo" style="height: 648; width: 704;"></div>
#         <script>
#         slider = new juxtapose.JXSlider('#foo',
#             [
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Satellite Image',
#                 },
#                 {
#                     src: 'data:image/jpg;base64,...',
#                     label: 'Image Segmentation',
#                 }
#             ],
#             {
#                 animate: true,
#                 showLabels: true,
#                 showCredits: true,
#                 startingPosition: "50%",
#                 makeResponsive: true,
#             });
#         </script>
# ...
